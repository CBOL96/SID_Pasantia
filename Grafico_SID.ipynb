# %%
import pandas as pd

# %%
path='C:/Users/Carlos/Downloads/Data/'
mediciones=pd.read_csv(path+"CITEC_NPM_2021-02-20.csv",names=['Fecha','Amplitud'],dtype={'Fecha':'str','Amplitud':'float64'})
datos=pd.DataFrame(mediciones)
datos['Fecha']=pd.to_datetime(datos['Fecha'])
datos.set_index('Fecha',drop=True, inplace=True)

# %%
datos.plot()
# Out:
# <AxesSubplot:>
